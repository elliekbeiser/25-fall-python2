# %%
def compliment():

    print('Enter your name:', flush=True)
    name = input() # You can ask for additional input within a function.
    print(f'{name} is most likely a decent person.', flush=True)
    print(flush=True) # prints a blank line for better formatting



def random_number():

    import random

    print(f'Your random number is {random.randint(1,10)}.', flush=True)
    print(flush=True) # prints a blank line for better formatting


def openfile():

    print(f'Enter file address:', flush=True)
    file_add = input()
    
    try:
        read_file = open(file_add)
        print(f'File successfully opened.')
    
    except: # If the user gave an invalid address, prompt them again by calling the openfile function again.
        print(f'Invalid file address. Please try again.')
        openfile()


# An example of how you might locate a Customer object based on their username.
# It's a good idea to write lots of short functions like this to handle you
def customerLookup():

    global customerList # Assumes that you have all Customer objects in a global list

    print(f'Enter customer username:', flush=True)
    requestedUsername = input()
    
    for cust in customerList:
        if cust.username == requestedUsername:
            return cust
    
    print(f'No such username.')
    customerLookup()


def interface():

    choice = ''
    while choice != '9':

        # Print the interface options
        print('Select an option:', flush=True)
        print("1: Get a half-hearted compliment.", flush=True)
        print("2: Get a random number.", flush=True)
        print("3: Open a file.", flush=True)
        print("9: Exit.", flush=True)
        print(flush=True) # prints a blank line for better formatting

        # Collect user input
        choice = input()
    
        if choice == '1':
            compliment()
        elif choice == '2':
            random_number()
        elif choice == '3':
            openfile()
        elif choice == '9':
            print("Shutting down...", flush=True)
        else:
            print("Please select an actual option.", flush=True)

# %%
interface()
# Out:
# Select an option:
# 1: Get a half-hearted compliment.
# 2: Get a random number.
# 3: Open a file.
# 9: Exit.
#
# Enter your name:
# ellie is most likely a decent person.
#
# Select an option:
# 1: Get a half-hearted compliment.
# 2: Get a random number.
# 3: Open a file.
# 9: Exit.
#
# Your random number is 4.
#
# Select an option:
# 1: Get a half-hearted compliment.
# 2: Get a random number.
# 3: Open a file.
# 9: Exit.
#
# Your random number is 8.
#
# Select an option:
# 1: Get a half-hearted compliment.
# 2: Get a random number.
# 3: Open a file.
# 9: Exit.
#
# Enter file address:
# Invalid file address. Please try again.
# Enter file address:
# File successfully opened.
# Select an option:
# 1: Get a half-hearted compliment.
# 2: Get a random number.
# 3: Open a file.
# 9: Exit.
#
# Shutting down...

# %%
def view_customers():

    print('Enter your customer id:', flush=True)
    id = input() # You can ask for additional input within a function.
    print(f'{id} has been selected', flush=True)
    print(flush=True) # prints a blank line for better formatting


def deposit():

    print('How much would you like to deposit?', flush=True)
    deposit_input = input()
    deposit_amount = float(deposit_input)
    if deposit_amount is float:
        print(f'Confirm the following deposit amount with Y or N: {deposit_amount}.', flush=True)
        confirmation = input()
        print(flush=True)
        
        if confirmation.upper() == 'Y':
            print(f'Your deposit of {deposit_amount} has been made')
            print(flush=True) # prints a blank line for better formatting
        elif confirmation.upper() == 'N':
            print('Invalid confirmation. Deposit not made')
            print(flush=True)
        else:
            print('Invalid confirmation. Deposit not made')
            print(flush=True)
    else:
        print('Amount for deposit must be a number')
        print(flush=True)
        


def openfile():

    print(f'Enter file address:', flush=True)
    file_add = input()
    
    try:
        read_file = open(file_add)
        print(f'File successfully opened.')
    
    except: # If the user gave an invalid address, prompt them again by calling the openfile function again.
        print(f'Invalid file address. Please try again.')
        openfile()


# An example of how you might locate a Customer object based on their username.
# It's a good idea to write lots of short functions like this to handle you
def customerLookup():

    global customerList # Assumes that you have all Customer objects in a global list

    print(f'Enter customer username:', flush=True)
    requestedUsername = input()
    
    for cust in customerList:
        if cust.username == requestedUsername:
            return cust
    
    print(f'No such username.')
    customerLookup()


def interface():

    choice = ''
    while choice != '6':

        # Print the interface options
        print('Select an option:', flush=True)
        print("1: View Customers", flush=True)
        print("2: Deposit", flush=True)
        print("3: Withdraw", flush=True)
        print("4: Credit Card Charge", flush=True)
        print("5: Credit Card Payment", flush=True)
        print("6: Exit.", flush=True)
        print(flush=True) # prints a blank line for better formatting

        # Collect user input
        choice = input()
    
        if choice == '1':
            view_customers()
        elif choice == '2':
            deposit()
        elif choice == '3':
            print('3')
        elif choice == '4':
            print('4')
        elif choice == '5':
            print('5')
        elif choice == '6':
            print("Shutting down...", flush=True)
        else:
            print("Please select an actual option.", flush=True)

# %%
deposit()
# Out:
# How much would you like to deposit?
# Amount for deposit must be a number

# %%
deposit_input = float(input())
deposit_amount = float(deposit_input)

# %%
print(type(deposit_input))
# Out:
# <class 'float'>
